# %%
# -*- coding: utf-8 -*-
"""
fig_c
"""

import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import operator
from functools import reduce
import pandas as pd   

f3_mae = list(reversed([0.09951419,0.09216836,0.07758381,0.07091389,0.063381985,0.06323322,0.056940854,0.05373428,0.052227188]))
f3_mse = list(reversed([0.019523572,0.017014582,0.011729621,0.00936434,0.007363748,0.007495695,0.005692222,0.005054365,0.004730405]))
f3 = [f3_mae,f3_mse]

f5_mae = list(reversed([0.10373783,0.09164648,0.07952156,0.06934295,0.064676024,0.058429576,0.057544656,0.05485599,0.050146293]))
f5_mse = list(reversed([0.023141876,0.017660767,0.013086657,0.008749036,0.007590336,0.006411052,0.005829227,0.005624576,0.004484041]))
f5 = [f5_mae,f5_mse]

f8_mae = list(reversed([0.10612221,0.09364353,0.076769404,0.0687976,0.06398491,0.060493577,0.059597753,0.054376315,0.051424574]))
f8_mse = list(reversed([0.025178242,0.0185801,0.011650601,0.008762991,0.007404429,0.006383517,0.00669646,0.005249288,0.004611112]))
f8 = [f8_mae,f8_mse]

f10_mae = list(reversed([0.111345425,0.09274911,0.08143405,0.07261498,0.062767714,0.060687114,0.054818533,0.052383255,0.051510505]))
f10_mse = list(reversed([0.027537758,0.019243147,0.013887564,0.009848455,0.00676172,0.006699899,0.00529169,0.004841766,0.004472836]))
f10 = [f10_mae,f10_mse]

pred_len = 24

import matplotlib.pyplot as plt
def fig(f3,f5,f8,f10): 
    
    colors = [['royalblue','dodgerblue'] ,  ['yellowgreen','darkolivegreen'] ,['mediumslateblue','darkslateblue']] 
    
    t = [1,2,3,4,5,6,7,8,9]

    plt.plot(t,f3, color="orange",linestyle = "--",marker='^',label='$c=3$',linewidth=1.2,markersize=5)
    plt.plot(t,f5, color="royalblue",linestyle = "--",marker='p',label='$c=5$',linewidth=1.2,markersize=5)
    plt.plot(t,f8, color="mediumpurple",linestyle = "--",marker='x',label='$c=8$',linewidth=1.2,markersize=5)
    plt.plot(t,f10, color="green",linestyle = "--",marker='o',label='$c=10$',linewidth=1.2,markersize=5)
    plt.xlabel('Prediction horizon')
    
    plt.legend(markerscale=0.6,framealpha=0.5,loc='upper left',
               labelspacing=0.1,borderpad=0.1)   #bbox_to_anchor=(0,0)

    plt.xticks(t,(1,3,6,10,16,24,32,48,64))#设置x刻度
    plt.xlabel('Prediction horizon')

plt.figure(figsize=(9,3))
plt.subplots_adjust(wspace=0.45,hspace=0.65)
matplotlib.rcParams.update({'font.size': 16})

ax1 = plt.subplot(121)
fig(f3[0],f5[0],f8[0],f10[0])
plt.ylabel('MAE')

ax2 = plt.subplot(122)
fig(f3[1],f5[1],f8[1],f10[1])
plt.ylabel('MSE')

#plt.savefig('./factor.png',dpi=600)
plt.show()

# %%
# -*- coding: utf-8 -*-
'''
fig_seq_len
'''
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import operator
from functools import reduce
import pandas as pd   

w96_mae = list(reversed([0.22139554,0.2197843,0.23202658,0.19718114,0.1629301,0.15854211,0.14019835,0.12192744,0.100514494]))
w96_mse = list(reversed([0.11563732,0.114274286,0.13350765,0.090116814,0.059761792,0.056599278,0.04322826,0.030701231,0.020373294]))
w96 = [w96_mae,w96_mse]

w64_mae = list(reversed([0.13313937,0.11635096,0.11587195,0.09320033,0.08767541,0.0828376,0.0715011,0.07048882,0.06631307]))
w64_mse = list(reversed([0.042353842,0.03016907,0.030333538,0.017535107,0.015790096,0.013086957,0.008695777,0.008990007,0.007393985]))
w64 = [w64_mae,w64_mse]

w48_mae = list(reversed([0.10373783,0.09164648,0.07952156,0.06934295,0.064676024,0.058429576,0.057544656,0.05485599,0.050146293]))
w48_mse = list(reversed([0.023141876,0.017660767,0.013086657,0.008749036,0.007590336,0.006411052,0.005829227,0.005624576,0.004484041]))
w48 = [w48_mae,w48_mse]

w32_mae = list(reversed([0.104133405,0.08695589,0.07597057,0.07134695,0.0639586,0.060783274,0.057770126,0.054864448,0.050620902]))
w32_mse = list(reversed([0.021346215,0.015010568,0.011295262,0.009909367,0.008113173,0.007495631,0.006611555,0.005916212,0.005070565]))
w32 = [w32_mae,w32_mse]

w24_mae = list(reversed([]))
w24_mse = list(reversed([]))
w24 = [w24_mae,w24_mse]

pred_len = 24



import matplotlib.pyplot as plt
def fig(w96,w64,w48,w32): 
    
    colors = [['royalblue','dodgerblue'] ,  ['yellowgreen','darkolivegreen'] ,['mediumslateblue','darkslateblue']] 
    
    t = [1,2,3,4,5,6,7,8,9]

    plt.plot(t,w32, color="green",linestyle = "--",marker='o',label='$ws=32$',linewidth=1.2,markersize=5)  
    plt.plot(t,w48, color="mediumpurple",linestyle = "--",marker='x',label='$ws=48$',linewidth=1.2,markersize=6)
    plt.plot(t,w64, color="royalblue",linestyle = "--",marker='p',label='$ws=64$',linewidth=1.2,markersize=6)
    plt.plot(t,w96, color="orange",linestyle = "--",marker='^',label='$ws=96$',linewidth=1.2,markersize=6)
    plt.xlabel('Prediction horizon')
    
    plt.legend(markerscale=0.6,framealpha=0.5,loc='upper left',
               labelspacing=0.1,borderpad=0.1)   #bbox_to_anchor=(0,0)

    plt.xticks(t,(1,3,6,10,16,24,32,48,64))#设置x刻度
    plt.xlabel('Prediction horizon')

plt.figure(figsize=(9,3))
plt.subplots_adjust(wspace=0.45,hspace=0.65)
matplotlib.rcParams.update({'font.size': 16})

ax1 = plt.subplot(121)
fig(w96[0],w64[0],w48[0],w32[0])
plt.ylabel('MAE')

ax2 = plt.subplot(122)
fig(w96[1],w64[1],w48[1],w32[1])
plt.ylabel('MSE')

#plt.savefig('./seq_len.png',dpi=600)
plt.show()

# %%
# -*- coding: utf-8 -*-
"""
fig_labels
"""

import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import operator
from functools import reduce
import pandas as pd   

l48_mae = list(reversed([0.10094054,0.08981196,0.07525982,0.070345074,0.062751494,0.057205968,0.055644553,0.051250685,0.049571346]))
l48_mse = list(reversed([0.021711344,0.01743291,0.010888542,0.009401128,0.006845725,0.006079668,0.005385826,0.00476179,0.004316411]))
l48 = [l48_mae,l48_mse]

l32_mae = list(reversed([0.10373783,0.09164648,0.07952156,0.06934295,0.064676024,0.058429576,0.057544656,0.05485599,0.050146293]))
l32_mse = list(reversed([0.023141876,0.017660767,0.013086657,0.008749036,0.007590336,0.006411052,0.005829227,0.005624576,0.004484041]))
l32 = [l32_mae,l32_mse]

l24_mae = list(reversed([0.10128148,0.090485364,0.07573535,0.07110278,0.06413467,0.059093606,0.0548457,0.05386115,0.05122777]))
l24_mse = list(reversed([0.021952221,0.016775578,0.010515498,0.009796731,0.007270075,0.005857618,0.005182088,0.005009181,0.004581297]))
l24 = [l24_mae,l24_mse]

l16_mae = list(reversed([0.10337796,0.09030591,0.07712032,0.067947544,0.061989307,0.056924976,0.055856593,0.05262831,0.050106388]))
l16_mse = list(reversed([0.022450048,0.017479349,0.010853959,0.00810509,0.006624299,0.005654754,0.00545663,0.004877844,0.004261091]))
l16 = [l16_mae,l16_mse]

pred_len = 24

import matplotlib.pyplot as plt
def fig(l48,l32,l24,l16): 
    
    colors = [['royalblue','dodgerblue'] ,  ['yellowgreen','darkolivegreen'] ,['mediumslateblue','darkslateblue']] 
    
    t = [1,2,3,4,5,6,7,8,9]

    plt.plot(t,l16, color="green",linestyle = "--",marker='o',label='$lm=16$',linewidth=1.2,markersize=5)  
    plt.plot(t,l24, color="mediumpurple",linestyle = "--",marker='x',label='$lm=24$',linewidth=1.2,markersize=6)
    plt.plot(t,l32, color="royalblue",linestyle = "--",marker='p',label='$lm=32$',linewidth=1.2,markersize=6)
    plt.plot(t,l48, color="orange",linestyle = "--",marker='^',label='$lm=48$',linewidth=1.2,markersize=6)
    plt.xlabel('Prediction horizon')
    
    plt.legend(markerscale=0.6,framealpha=0.5,loc='upper left',
               labelspacing=0.1,borderpad=0.1)   #bbox_to_anchor=(0,0)

    plt.xticks(t,(1,3,6,10,16,24,32,48,64))#设置x刻度
    plt.xlabel('Prediction horizon')

plt.figure(figsize=(9,3))
plt.subplots_adjust(wspace=0.45,hspace=0.65)
matplotlib.rcParams.update({'font.size': 16})

ax1 = plt.subplot(121)
fig(l48[0],l32[0],l24[0],l16[0])
plt.ylabel('MAE')


ax2 = plt.subplot(122)
fig(l48[1],l32[1],l24[1],l16[1])
plt.ylabel('MSE')


#plt.savefig('./label_len.png',dpi=600)
plt.show()
